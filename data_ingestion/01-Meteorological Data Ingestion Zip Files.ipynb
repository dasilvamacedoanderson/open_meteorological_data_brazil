# %%
import requests
import urllib

# %%
dirDestine = r"/Volumes/open_meteorological_data_brazil/bronze/zipfileraw"

# %%
def landingFileFromUrl(url, local_filename):
    print(f"Loading data {local_filename}")

    urllib.request.urlretrieve(url, f'{dirDestine}/{local_filename}')
    # urllib.request.urlretrieve(url, f'{dirDestine}/{local_filename}')
    return local_filename

# %%
#Get the file from Url
year = int(dbutils.widgets.get("numAno"))
print(f"Start Process Year {year}")
url = f"https://portal.inmet.gov.br/uploads/dadoshistoricos/{year}.zip"
fileName = f"open_meteorological_data_brazil_{year}.zip"
landingFileFromUrl(url, f"{fileName}")
print(f"{year} zip file downloaded")
